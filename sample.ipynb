# %%
import iparacoord
from sklearn import datasets, tree
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Classification

# %%
iris = datasets.load_iris()
X, y = iris.data, iris.target
estimator = tree.DecisionTreeClassifier(max_depth=2).fit(X, y)
pct = iparacoord.ParallelCoordinatesTree(estimator)
pct.visualize(X, y, feature_names=iris.feature_names, target_names=iris.target_names)
# Out:
#   <div class="bk-root" id="e7b8a717-f45b-403c-993a-d1d84d9867a5" data-root-id="1002"></div>

# %%
wine = datasets.load_wine()
X, y = wine.data, wine.target
estimator = tree.DecisionTreeClassifier(max_depth=3).fit(X, y)
pct = iparacoord.ParallelCoordinatesTree(estimator)
pct.visualize(X, y, feature_names=wine.feature_names, target_names=wine.target_names)
# Out:
#   <div class="bk-root" id="8adf95a4-bacb-4c8d-8b79-dc2389a839a9" data-root-id="5576"></div>

# %%
cancer = datasets.load_breast_cancer()
X, y = cancer.data, cancer.target
estimator = tree.DecisionTreeClassifier(max_depth=3).fit(X, y)
pct = iparacoord.ParallelCoordinatesTree(estimator)
pct.visualize(X, y, feature_names=cancer.feature_names, target_names=cancer.target_names)
# Out:
#   <div class="bk-root" id="d6273609-9e2a-4b87-9321-8d3d23065dbb" data-root-id="12131"></div>

# %% [markdown]
# # Regression

# %%
boston = datasets.load_boston()
X, y = boston.data, boston.target
estimator = tree.DecisionTreeRegressor(max_depth=2).fit(X, y)
pct = iparacoord.ParallelCoordinatesTree(estimator)
pct.visualize(X, y, feature_names=boston.feature_names, target_names=['MEDV'])
# Out:
#   <div class="bk-root" id="6c4b6585-e412-49ab-b2df-10c9372a54bc" data-root-id="28281"></div>

# %%
diabetes = datasets.load_diabetes()
X, y = diabetes.data, diabetes.target
estimator = tree.DecisionTreeRegressor(max_depth=2).fit(X, y)
pct = iparacoord.ParallelCoordinatesTree(estimator)
pct.visualize(X, y, feature_names=diabetes.feature_names, target_names=['outcome'])
# Out:
#   <div class="bk-root" id="510d1802-561e-43c2-bcaf-c17d704e9fb3" data-root-id="41318"></div>

# %%
linnerud = datasets.load_linnerud()
X, y = linnerud.data, linnerud.target
estimator = tree.DecisionTreeRegressor(max_depth=2).fit(X, y)
pct = iparacoord.ParallelCoordinatesTree(estimator)
pct.visualize(X, y, feature_names=linnerud.feature_names, target_names=linnerud.target_names, target_index=0)
# Out:
#   <div class="bk-root" id="e0a81334-8867-4203-9608-afe953bf0b21" data-root-id="54059"></div>

# %% [markdown]
# # Prediction Path

# %%
wine = datasets.load_wine()
X, y = wine.data, wine.target
estimator = tree.DecisionTreeClassifier(max_depth=3).fit(X, y)
pct = iparacoord.ParallelCoordinatesTree(estimator)
pct.visualize(X, y, feature_names=wine.feature_names, target_names=wine.target_names)
# Out:
#   <div class="bk-root" id="97744e09-9b7d-451f-97c4-22b0903c824b" data-root-id="58761"></div>

# %%
pct.predict(X[0])
# Out:
# <style  type="text/css" >
#     #T_c427b1ba_d1fe_11e9_b4fb_e4b318778f20row0_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_c427b1ba_d1fe_11e9_b4fb_e4b318778f20row0_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_c427b1ba_d1fe_11e9_b4fb_e4b318778f20row0_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_c427b1ba_d1fe_11e9_b4fb_e4b318778f20row0_col11 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  #000000;
# ...
